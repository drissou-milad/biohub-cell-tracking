# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import matplotlib.pyplot as plt
import numpy as np

from src import config

# %%
from src.dataset import BioHubDataset
from src.detector import CellDetector
from src.tracker import HungarianTracker  # was `NearestNeighborTracker`, which doesn't exist in src/tracker.py

# %%
DATASET = BioHubDataset(config.DATASET_PATH)

sample = DATASET.train_samples[0]

volume = DATASET.load_volume(sample)

print(volume.shape)
# Out:
# (100, 64, 256, 256)

# %%
detector = CellDetector(    sigma=2,
    threshold_abs=1800,
    min_distance=12,
)

detections = detector.detect_volume(volume)

print(len(detections))

print(detections[0][:5])
# Out:
# 100
# [[179  82]
#  [113 217]
#  [104  84]
#  [170 185]
#  [101 171]]

# %%
tracker = HungarianTracker(max_distance=25)

tracks = tracker.track(detections)

print(len(tracks))
print(tracks[0])
# Out:
# 99
# [{'previous': np.int64(0), 'current': np.int64(2), 'distance': np.float64(5.0)}, {'previous': np.int64(2), 'current': np.int64(4), 'distance': np.float64(1.4142135623730951)}, {'previous': np.int64(3), 'current': np.int64(16), 'distance': np.float64(5.656854249492381)}, {'previous': np.int64(4), 'current': np.int64(3), 'distance': np.float64(3.605551275463989)}, {'previous': np.int64(6), 'current': np.int64(5), 'distance': np.float64(2.0)}, {'previous': np.int64(7), 'current': np.int64(7), 'distance': np.float64(5.385164807134504)}, {'previous': np.int64(8), 'current': np.int64(10), 'distance': np.float64(2.23606797749979)}, {'previous': np.int64(9), 'current': np.int64(11), 'distance': np.float64(1.4142135623730951)}, {'previous': np.int64(10), 'current': np.int64(14), 'distance': np.float64(4.242640687119285)}, {'previous': np.int64(11), 'current': np.int64(8), 'distance': np.float64(4.123105625617661)}, {'previous': np.int64(12), 'current': np.int64(12), 'distance': np.float64(4.47213595499958)}, {'previous': np.int64(13), 'current': np.int64(18), 'distance': np.float64(3.0)}, {'previous': np.int64(14), 'current': np.int64(15), 'distance': np.float64(5.0)}, {'previous': np.int64(15), 'current': np.int64(24), 'distance': np.float64(7.0710678118654755)}, {'previous': np.int64(16), 'current': np.int64(33), 'distance': np.float64(4.123105625617661)}, {'previous': np.int64(17), 'current': np.int64(13), 'distance': np.float64(2.8284271247461903)}, {'previous': np.int64(18), 'current': np.int64(17), 'distance': np.float64(5.385164807134504)}, {'previous': np.int64(19), 'current': np.int64(6), 'distance': np.float64(5.0)}, {'previous': np.int64(20), 'current': np.int64(19), 'distance': np.float64(2.0)}, {'previous': np.int64(21), 'current': np.int64(26), 'distance': np.float64(5.0990195135927845)}, {'previous': np.int64(22), 'current': np.int64(9), 'distance': np.float64(2.23606797749979)}, {'previous': np.int64(23), 'current': np.int64(29), 'distance': np.float64(6.082762530298219)}, {'previous': np.int64(24), 'current': np.int64(32), 'distance': np.float64(3.605551275463989)}, {'previous': np.int64(25), 'current': np.int64(25), 'distance': np.float64(2.8284271247461903)}, {'previous': np.int64(26), 'current': np.int64(21), 'distance': np.float64(14.317821063276353)}, {'previous': np.int64(27), 'current': np.int64(27), 'distance': np.float64(3.605551275463989)}, {'previous': np.int64(28), 'current': np.int64(20), 'distance': np.float64(2.23606797749979)}, {'previous': np.int64(30), 'current': np.int64(34), 'distance': np.float64(1.4142135623730951)}, {'previous': np.int64(31), 'current': np.int64(35), 'distance': np.float64(4.47213595499958)}, {'previous': np.int64(32), 'current': np.int64(30), 'distance': np.float64(10.04987562112089)}, {'previous': np.int64(33), 'current': np.int64(0), 'distance': np.float64(22.47220505424423)}, {'previous': np.int64(34), 'current': np.int64(31), 'distance': np.float64(6.4031242374328485)}]
